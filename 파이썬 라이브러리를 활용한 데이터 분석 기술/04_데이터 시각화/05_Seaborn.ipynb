# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 그래프를 그리기 위한 기본 설정
# 폰트설정 - 윈도우
plt.rcParams['font.family'] = 'Malgun Gothic'

# 폰트설정 - 맥
# plt.rcParams['font.family'] = 'Apple Gothic'

# 그래프의 크기
plt.rcParams['figure.figsize'] = 12, 6

# 글자 크기
plt.rcParams['font.size'] = 14

# 폰트 설정 시 '-'기호 깨는거 방지하기
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 1차원 분포 플롯
# - 데이터의 분포를 확인하기 위해서 산점도(scatter)를 사용한다.
# - 산점도는 x축과 y축이 지정되어야 하기 때문에 1차원 데이터는 표현할 수 없다.
# - 이에 seaborn에서 1차원 데이터의 분포를 볼 수 있는 것을 제공한다.

# %%
iris = pd.read_csv('data/iris.csv')
iris.columns = ['꽃받침길이', '꽃받침너비', '꽃잎길이', '꽃잎너비', '품종']
iris
# Out:
#      꽃받침길이  꽃받침너비  꽃잎길이  꽃잎너비         품종
# 0      5.1    3.5   1.4   0.2     setosa
# 1      4.9    3.0   1.4   0.2     setosa
# 2      4.7    3.2   1.3   0.2     setosa
# 3      4.6    3.1   1.5   0.2     setosa
# 4      5.0    3.6   1.4   0.2     setosa
# ..     ...    ...   ...   ...        ...
# 145    6.7    3.0   5.2   2.3  virginica
# 146    6.3    2.5   5.0   1.9  virginica
# 147    6.5    3.0   5.2   2.0  virginica
# 148    6.2    3.4   5.4   2.3  virginica
# 149    5.9    3.0   5.1   1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Rug Plot
# 1차원 데이터에 저장되어 있는 값들의 종류를 확인할 수 있다.
# 각 값들이 얼마나 저장되어 있는지 확인할 수는 없다.
sns.rugplot(iris['꽃잎길이'])
plt.title('꽃잎 길이에 대한 Rug Plot')
plt.show()

# %%
# kde : 커널 함수를 이용해 밀도를 표현한다.
# 히스토그램을 통해 구간별 값의 개수를 파악할 수 있다. 히스토그램은 막대 그래프로 표현하지만 kde는 선 그래프로 각 값의 개수를 파악할 수 있다.
sns.kdeplot(iris['꽃잎길이'])
plt.title('kde plot')
plt.show()

# %%
# displot : 러그와 커널 밀도를 같이 표현하는 함수
# 표시되는 막대 그래프는 각 구간별 값의 종류 수를 표시한다.
sns.displot(iris['꽃잎길이'], kde=True, rug=True)
plt.title('displot')
plt.show()

# %% [markdown]
# ### 카운트 플롯
# - 특정 컬럼의 데이터의 개수를 막대 그래프로 표현한 그래프
# - 특정된 컬럼의 데이터의 각 종류별로 몇 개씩 저장되어 있는지 확인할 수 있는 그래프이다.
# - 간단하게 그릴 수 있다는 장점을 가지고 있고 matplotlib이나 데이터 프레임을 통해 그래프를 그릴 때 오류가 발생하는 부분을 해결한 그래프.

# %%
sns.countplot(data=iris, x='품종')
plt.title('count plot')
plt.show()

# %% [markdown]
# ### 다차원 데이터
# - 데이터 변수가 여러 개인 다차원 데이터를 표현할 수 있다.
# - 분석하고자 하는 데이터가 모두 범위 갑인 경우
# - 분석하고자 하는 데이터가 모두 카테고리 값인 경우
# - 분석하고자 하는 데이터가 모두 범위형과 카테고리형이 섞여 있는 경우

# %% [markdown]
# ### 2차원 실수형 데이터

# %%
# jointplot: 산점도와 히스토그램이 같이 표현된다.
sns.jointplot(x='꽃받침길이', y='꽃받침너비', data=iris)
plt.suptitle('jointplot', y =1.02)
plt.show()

# %%
# kind에 kde를 넣어지면 kde 커널 밀도 히스토그램으 그릴 수 있다.
sns.jointplot(x='꽃받침길이', y='꽃받침너비', data=iris, kind='kde')
plt.suptitle('jointplot의 kde 밀도 히스토그램', y=1.02)
plt.show()

# %% [markdown]
# ### PairPlot
# - 산점도의 경우에는 2차원 데이터. 즉 컬럼 두 개를 지정하여 표현한다.
# - 만약 데이터 프레임의 컬럼이 다수인 경우 산점도를 그리려면 개발자가 꽤 많은 그래프를 그려야한다.
# - PariPlot은 데이터 프레임의 각 컬럼들을 조합한 산점도를 모두 표현해준다.
# - 여기에 히스토그램도 같이 표현해준다.

# %%
sns.pairplot(iris)
plt.suptitle('pair plot', y =1.02)
plt.show()

# %%
# hue: 결과 데이터에 해당하는 컬럼을 지정한다.
# 지정된 컬럼의 값이 똑탙은 것끼리 같은 색으로 표시한다.
sns.pairplot(iris, hue='품종')
plt.suptitle('pair plot', y =1.02)
plt.show()

# %% [markdown]
# ### Heatmap
# - 컬럼 간의 상관관계나 데이터의 양을 색상으로 표현해 확인하는 그래프.
